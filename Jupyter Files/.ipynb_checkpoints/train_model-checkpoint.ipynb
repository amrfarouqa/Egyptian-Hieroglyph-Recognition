# %%
from pickle import load
from numpy import array
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical
from keras.utils.vis_utils import plot_model
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import Embedding
from keras.layers import RepeatVector
from keras.layers import TimeDistributed
from keras.callbacks import ModelCheckpoint

# %%
# load a clean dataset
def load_clean_sentences(filename):
	return load(open(filename, 'rb'))

# %%
# fit a tokenizer
def create_tokenizer(lines):
	tokenizer = Tokenizer()
	tokenizer.fit_on_texts(lines)
	return tokenizer

# %%
# max sentence length
def max_length(lines):
	return max(len(line.split()) for line in lines)

# %%
# encode and pad sequences
def encode_sequences(tokenizer, length, lines):
	# integer encode sequences
	X = tokenizer.texts_to_sequences(lines)
	# pad sequences with 0 values
	X = pad_sequences(X, maxlen=length, padding='post')
	return X

# %%
# one hot encode target sequence
def encode_output(sequences, vocab_size):
	ylist = list()
	for sequence in sequences:
		encoded = to_categorical(sequence, num_classes=vocab_size)
		ylist.append(encoded)
	y = array(ylist)
	y = y.reshape(sequences.shape[0], sequences.shape[1], vocab_size)
	return y

# %%
# define NMT model
def define_model(src_vocab, tar_vocab, src_timesteps, tar_timesteps, n_units):
	model = Sequential()
	model.add(Embedding(src_vocab, n_units, input_length=src_timesteps, mask_zero=True))
	model.add(LSTM(n_units))
	model.add(RepeatVector(tar_timesteps))
	model.add(LSTM(n_units, return_sequences=True))
	model.add(TimeDistributed(Dense(tar_vocab, activation='softmax')))
	return model

# %%
# load datasets
dataset = load_clean_sentences('../PKL Files/english-hiero-both.pkl')
train = load_clean_sentences('../PKL Files/english-hiero-train.pkl')
test = load_clean_sentences('../PKL Files/english-hiero-test.pkl')

# %%
# prepare english tokenizer
eng_tokenizer = create_tokenizer(dataset[:, 0])
eng_vocab_size = len(eng_tokenizer.word_index) + 1
eng_length = max_length(dataset[:, 0])
print('English Vocabulary Size: %d' % eng_vocab_size)
print('English Max Length: %d' % (eng_length))
# prepare hieroglyph tokenizer
ger_tokenizer = create_tokenizer(dataset[:, 1])
ger_vocab_size = len(ger_tokenizer.word_index) + 1
ger_length = max_length(dataset[:, 1])
print('Hieroglyph Vocabulary Size: %d' % ger_vocab_size)
print('Hieroglyph Max Length: %d' % (ger_length))
# Out:
# English Vocabulary Size: 12206
# English Max Length: 14
# Hieroglyph Vocabulary Size: 12206
# Hieroglyph Max Length: 14

# %%
# prepare training data
trainX = encode_sequences(ger_tokenizer, ger_length, train[:, 1])
trainY = encode_sequences(eng_tokenizer, eng_length, train[:, 0])
trainY = encode_output(trainY, eng_vocab_size)
# prepare validation data
testX = encode_sequences(ger_tokenizer, ger_length, test[:, 1])
testY = encode_sequences(eng_tokenizer, eng_length, test[:, 0])
testY = encode_output(testY, eng_vocab_size)

# %%
# define model
model = define_model(ger_vocab_size, eng_vocab_size, ger_length, eng_length, 256)
model.compile(optimizer='adam', loss='categorical_crossentropy')

# %%
# summarize defined model
print(model.summary())
plot_model(model, to_file='../PNG Files/model.png', show_shapes=True)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 14, 256)           3124736
# _________________________________________________________________
# lstm (LSTM)                  (None, 256)               525312
# _________________________________________________________________
# repeat_vector (RepeatVector) (None, 14, 256)           0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 14, 256)           525312
# _________________________________________________________________
# time_distributed (TimeDistri (None, 14, 12206)         3136942
# =================================================================
# Total params: 7,312,302
# Trainable params: 7,312,302
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# fit model
filename = '../Model Files/model.h5'
checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
model.fit(trainX, trainY, epochs=30, batch_size=64, validation_data=(testX, testY), callbacks=[checkpoint], verbose=2)
# Out:
# Epoch 1/30
# 782/782 - 1542s - loss: 2.9871 - val_loss: 2.6432
#
# Epoch 00001: val_loss improved from inf to 2.64324, saving model to ../Model Files/model.h5
# Epoch 2/30
# 782/782 - 1571s - loss: 2.5665 - val_loss: 2.5323
#
# Epoch 00002: val_loss improved from 2.64324 to 2.53228, saving model to ../Model Files/model.h5
# Epoch 3/30
# 782/782 - 1598s - loss: 2.3713 - val_loss: 2.2275
#
# Epoch 00003: val_loss improved from 2.53228 to 2.22749, saving model to ../Model Files/model.h5
# Epoch 4/30
# 782/782 - 1630s - loss: 2.0025 - val_loss: 1.8550
#
# Epoch 00004: val_loss improved from 2.22749 to 1.85501, saving model to ../Model Files/model.h5
# Epoch 5/30
# 782/782 - 1630s - loss: 1.6254 - val_loss: 1.5199
#
# Epoch 00005: val_loss improved from 1.85501 to 1.51987, saving model to ../Model Files/model.h5
# Epoch 6/30
# 782/782 - 1652s - loss: 1.2797 - val_loss: 1.2163
#
# Epoch 00006: val_loss improved from 1.51987 to 1.21635, saving model to ../Model Files/model.h5
# Epoch 7/30
# 782/782 - 1659s - loss: 1.0063 - val_loss: 1.0179
#
# Epoch 00007: val_loss improved from 1.21635 to 1.01792, saving model to ../Model Files/model.h5
# Epoch 8/30
# 782/782 - 1668s - loss: 0.7911 - val_loss: 0.8439
#
# Epoch 00008: val_loss improved from 1.01792 to 0.84386, saving model to ../Model Files/model.h5
# Epoch 9/30
# 782/782 - 1684s - loss: 0.6164 - val_loss: 0.7202
#
# Epoch 00009: val_loss improved from 0.84386 to 0.72016, saving model to ../Model Files/model.h5
# Epoch 10/30
# 782/782 - 1676s - loss: 0.4789 - val_loss: 0.6341
#
# Epoch 00010: val_loss improved from 0.72016 to 0.63414, saving model to ../Model Files/model.h5
# Epoch 11/30
# 782/782 - 1679s - loss: 0.3706 - val_loss: 0.5582
#
# Epoch 00011: val_loss improved from 0.63414 to 0.55821, saving model to ../Model Files/model.h5
# Epoch 12/30
# 782/782 - 1684s - loss: 0.2844 - val_loss: 0.5072
#
# Epoch 00012: val_loss improved from 0.55821 to 0.50716, saving model to ../Model Files/model.h5
# Epoch 13/30
# 782/782 - 1683s - loss: 0.2165 - val_loss: 0.4751
#
# Epoch 00013: val_loss improved from 0.50716 to 0.47505, saving model to ../Model Files/model.h5
# Epoch 14/30
# 782/782 - 1680s - loss: 0.1667 - val_loss: 0.4573
#
# Epoch 00014: val_loss improved from 0.47505 to 0.45735, saving model to ../Model Files/model.h5
# Epoch 15/30
# 782/782 - 1695s - loss: 0.1316 - val_loss: 0.4249
#
# Epoch 00015: val_loss improved from 0.45735 to 0.42485, saving model to ../Model Files/model.h5
# Epoch 16/30
# 782/782 - 1680s - loss: 0.1051 - val_loss: 0.4231
#
# Epoch 00016: val_loss improved from 0.42485 to 0.42309, saving model to ../Model Files/model.h5
# Epoch 17/30
# 782/782 - 1688s - loss: 0.0847 - val_loss: 0.3925
#
# Epoch 00017: val_loss improved from 0.42309 to 0.39247, saving model to ../Model Files/model.h5
# Epoch 18/30
# 782/782 - 1675s - loss: 0.0703 - val_loss: 0.3818
#
# Epoch 00018: val_loss improved from 0.39247 to 0.38178, saving model to ../Model Files/model.h5
# Epoch 19/30
# 782/782 - 1663s - loss: 0.0592 - val_loss: 0.3810
#
# Epoch 00019: val_loss improved from 0.38178 to 0.38104, saving model to ../Model Files/model.h5
# Epoch 20/30
# 782/782 - 1681s - loss: 0.0482 - val_loss: 0.3868
#
# Epoch 00020: val_loss did not improve from 0.38104
# Epoch 21/30
# 782/782 - 1672s - loss: 0.0446 - val_loss: 0.3730
#
# Epoch 00021: val_loss improved from 0.38104 to 0.37301, saving model to ../Model Files/model.h5
# Epoch 22/30
# 782/782 - 1681s - loss: 0.0368 - val_loss: 0.3748
#
# Epoch 00022: val_loss did not improve from 0.37301
# Epoch 23/30
# 782/782 - 1677s - loss: 0.0364 - val_loss: 0.3836
#
# Epoch 00023: val_loss did not improve from 0.37301
# Epoch 24/30
# 782/782 - 1685s - loss: 0.0300 - val_loss: 0.3654
#
# Epoch 00024: val_loss improved from 0.37301 to 0.36537, saving model to ../Model Files/model.h5
# Epoch 25/30
# 782/782 - 1675s - loss: 0.0254 - val_loss: 0.3720
#
# Epoch 00025: val_loss did not improve from 0.36537
# Epoch 26/30
# 782/782 - 1680s - loss: 0.0239 - val_loss: 0.3596
#
# Epoch 00026: val_loss improved from 0.36537 to 0.35961, saving model to ../Model Files/model.h5
# Epoch 27/30
# 782/782 - 1694s - loss: 0.0215 - val_loss: 0.3643
#
# Epoch 00027: val_loss did not improve from 0.35961
# Epoch 28/30
# 782/782 - 1680s - loss: 0.0194 - val_loss: 0.3601
#
# Epoch 00028: val_loss did not improve from 0.35961
# Epoch 29/30
# 782/782 - 1689s - loss: 0.0263 - val_loss: 0.3628
#
# Epoch 00029: val_loss did not improve from 0.35961
# Epoch 30/30
# 782/782 - 1698s - loss: 0.0166 - val_loss: 0.3588
#
# Epoch 00030: val_loss improved from 0.35961 to 0.35881, saving model to ../Model Files/model.h5
